# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('dataset.csv')
dataset.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dataset
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# Columns Metadata:
#
# carat: berat diamond
#
# cut: kualitas diamond
#
# color: warna diamond
#
# clarity: level kemurnian diamonds
#
# depth: tinggi dari diamond tabel
#
# table: lebar  dari diamond tabel
#
# price: harga diamond ($US)
#
# x: panjang
#
# y: lebar
#
# z: kedalaaman

# %% [markdown]
# ## Cari rata-rata dari kolom depth, table dan price. Lalu cari nilai yang paling banyak dari kolom color dan clarity

# %%
#Code Here

# %% [markdown]
# ## Groupby kolom cut dan aggregasi secara rata-rata

# %%
#Code Here

# %%
#Expected Output
# Out:
#               carat      depth      table        price         x         y  \
# cut
# Fair       1.046137  64.041677  59.053789  4358.757764  6.246894  6.182652
# Good       0.849185  62.365879  58.694639  3928.864452  5.838785  5.850744
# Ideal      0.702837  61.709401  55.951668  3457.541970  5.507451  5.520080
# Premium    0.891955  61.264673  58.746095  4584.257704  5.973887  5.944879
# Very Good  0.806381  61.818275  57.956150  3981.759891  5.740696  5.770026
#
#                   z
# cut
# Fair       3.982770
# Good       3.639507
# Ideal      3.401448
# Premium    3.647124
# Very Good  3.559801

# %% [markdown]
# ## Grouping Beberapa Kolom dari Banyak Kriteria

# %% [markdown]
# Groupby data berdasarkan cut dan color, aggregasi terhadap kolom carat, table, depth dan price secara rata-rata dan median
# 1. Berapa harga dengan cut premium dan warna nya D?
# 2. Berapa karat yang berkriteria fair dan berwarna E?
# 3. Berapa nilai median dari carat, depth, table dan price dengan cut good, color E?

# %%
#Code Here

# %%
#Expected Output
# Out:
#                     carat             depth             table         \
#                      mean median       mean median       mean median
# cut       color
# Fair      D      0.920123  0.900  64.048466   64.8  58.969325   58.0
#           E      0.856607  0.900  63.319643   64.8  59.364732   59.0
#           F      0.904712  0.900  63.508013   64.8  59.453205   59.0
#           G      1.023822  0.980  64.339809   65.0  58.773248   58.0
#           H      1.219175  1.010  64.585149   65.1  58.696370   58.0
#           I      1.198057  1.010  64.220571   65.1  59.237143   58.0
#           J      1.341176  1.030  64.357143   65.0  58.917647   58.0
# Good      D      0.744517  0.700  62.365710   63.4  58.541541   58.0
#           E      0.745134  0.700  62.203751   63.3  58.779957   58.0
#           F      0.775930  0.710  62.202310   63.2  58.910891   59.0
#           G      0.850896  0.900  62.526636   63.4  58.471986   58.0
# ...

# %% [markdown]
# ## Carilah nilai max, min dan rata-rata harga dari kategori cut

# %%
groupb = dataset.groupby(['cut'])

# %%
#Expected Output
# Out:
# cut
# Fair         18574
# Good         18788
# Ideal        18806
# Premium      18823
# Very Good    18818
# Name: price, dtype: int64

# %%
#Expected Output
# Out:
# cut
# Fair         337
# Good         327
# Ideal        326
# Premium      326
# Very Good    336
# Name: price, dtype: int64

# %%
#Expected Output
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
# ## Plot nilai max dan min harga dari kategori cut kedalam barplot

# %%
plotmaxmin = pd.DataFrame({
    "maximum":maxim,
    "minimum":minim,
    "rata-rata":rata
})

# %%
#Code Here

# %%
#Expected Output
# Out:
# Text(0, 0.5, 'Harga')
